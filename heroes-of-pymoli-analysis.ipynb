# %% [markdown]
# ## Heroes Of Pymoli Data Analysis
#
# ###### Purpose
# ###### Dataset
# * clean_purchase_data.csv
# _____
#
# ##### Analysis (Observable Trends):
# *
#
# *
#
# *
# _____
#
# ##### Documentation
# * <unique_items>
# * <average_price>
# * <total_purchases>
# * <total_revenue>
# * <total_players>
# _____

# %% [markdown]
# ### Setup

# %%
# Dependencies
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
purchase_data = 'data/clean_purchase_data.csv'

# Read Purchasing File and store into Pandas data frame
purchase_df = pd.read_csv(purchase_data)

# %%
# Print the first five rows of data to the screen
purchase_df.head()
# Out:
#    Purchase ID         Player  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Basic Calculations stored in variables:

# Number of unique items
unique_items = purchase_df['Item ID'].nunique()

# Average price
average_price = purchase_df['Price'].mean()

# Number of purchases
total_purchases = purchase_df['Purchase ID'].count()

# Total revenue
total_revenue = purchase_df['Price'].sum()

# Unique players
total_players = purchase_df['Player'].nunique()

# %% [markdown]
# _____
# ### Player Count
# * Display the total number of players

# %%
# Return number of unique elements in 'Player' column
player_count_df = pd.DataFrame({
    'Total Players': [purchase_df['Player'].nunique(dropna=True)]
})

player_count_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# _____
#
# ### Purchasing Analysis (Total)
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# # Number of unique items
# unique_items = purchase_df['Item ID'].nunique()

# # Average price
# average_price = purchase_df['Price'].mean()

# # Number of purchases
# total_purchases = purchase_df['Purchase ID'].count()

# # Total revenue
# total_revenue = purchase_df['Price'].sum()

# %%
# Create and display a summary data frame using above values
totals_summary_df = pd.DataFrame({'Number of Unique Items': [unique_items],
                           'Average Price': '${:,.2f}'.format(average_price),
                           'Number of Purchases': [total_purchases],
                           'Total Revenue': '${:,.2f}'.format(total_revenue)})

totals_summary_df
# totals_summary_df.dtypes
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780     $2,379.77

# %% [markdown]
# _____
#
# ### Gender Demographics
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Create new df
gender_df = purchase_df[['Gender','Player']]
gender_df.head()
# Out:
#   Gender         Player
# 0   Male        Lisim78
# 1   Male    Lisovynya38
# 2   Male     Ithergue48
# 3   Male  Chamassasya86
# 4   Male      Iskosia90

# %%
# Drop duplicate rows
gender_unique_df = gender_df.drop_duplicates()

# %%
# Drop player column
gender_unique_df.drop(columns=['Player'])

# Verify col was dropped
gender_unique_df.head()
# Out:
#   Gender         Player
# 0   Male        Lisim78
# 1   Male    Lisovynya38
# 2   Male     Ithergue48
# 3   Male  Chamassasya86
# 4   Male      Iskosia90

# %%
# Calculate unique counts for each gender and return results in a dataframe
gender_counts = gender_unique_df['Gender'].value_counts()
gender_summary_df = gender_counts.to_frame()
gender_summary_df
# Out:
#                        Gender
# Male                      484
# Female                     81
# Other / Non-Disclosed      11

# %%
# Calculate 'Percentage of Players' and round to two decimal places
player_percentage = round((gender_summary_df['Gender'] / total_players) * 100, 2)
player_percentage
# Out:
# Male                     84.03
# Female                   14.06
# Other / Non-Disclosed     1.91
# Name: Gender, dtype: float64

# %%
# Add new column for percentages to the dataframe
gender_summary_df['Percentage of Players'] = player_percentage
gender_summary_df
# Out:
#                        Gender  Percentage of Players
# Male                      484                  84.03
# Female                     81                  14.06
# Other / Non-Disclosed      11                   1.91

# %% [markdown]
# _____
#
# ### Purchasing Analysis (Gender)
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame
#
# ***SEE: http://localhost:8890/notebooks/UTAUS201810DATA2-copy/04_Pandas/2/Activities/06-Ins_GroupBy/Solved/GroupBy.ipynb***

# %%
# DELETE THIS SECTION (only for quick reference)
# Print the first five rows of purchase_df data to the screen
purchase_df.head()
# Out:
#    Purchase ID         Player  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
# Unique players
total_players = purchase_df['Player'].nunique()

# # Total purchases per player
# avg_per_player = purchase_df['Price']

# purchase_df['Price'].sum()

# %%
# purchase_df.groupby('Gender', as_index=False).agg({'Purchase ID':'count', 'Price':'mean', 'Price': 'sum'})

# # purchase_df.groupby('Gender').agg({'Purchase ID':'count',
#                                   'Price':'mean',
#                                   })

# d['Avg Total Purchase per Person'] = (....)
            
# ______

# Use groupby to separate the data into fields according to 'Gender' values
# grouped_gender = purchase_df.groupby(['Gender'])

# Use a data function to visualize
# grouped_gender.nunique().head()

# Need to calculate d['Avg Total Purchase per Person'] = x[] and add to formula f

def f(x):
    d = {}
    d['Purchase Count'] = x['Purchase ID'].count()
    d['Average Purchase Price'] = x['Price'].mean()
    d['Total Purchase Value'] = x['Price'].sum()
    return pd.Series(d, index=['Purchase Count', 'Average Purchase Price', 'Total Purchase Value', 'Avg Total Purchase per Person'])

purchase_df.groupby('Gender').apply(f)
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                            NaN
# Male                                1967.64                            NaN
# Other / Non-Disclosed                 50.19                            NaN

# %%
#     d['Avg Total Purchase per Person'] = (sum of unique player purchase price) / (total number of unique player purchases)

# Calculate sum of price per player

# # Create function that returns total purchase value
# def f2(x):
#     d = {}
#     d['Purchase Value'] = x['Price'].sum()
#     d['Purchase Count'] = x['Purchase ID'].count()
#     return pd.Series(d, index=['Purchase Value', 'Purchase Count'])

# purchase_df.groupby('Player').apply(f2)

# #purchase_df.groupby('Gender').apply(f2)

# Create function that returns total purchase value
def f3(x):
    d = {}
    d['Purchase Value'] = x['Price'].sum()
    d['Purchase Count'] = x['Purchase ID'].count()
    d['Purchase Average'] = (x['Price'].sum() / x['Purchase ID'].count())
    d['Average Total Purchase per Person'] = []
    return pd.Series(d)

purchase_df.groupby('Player').apply(f3)
# Out:
#                  Purchase Value  Purchase Count  Purchase Average  \
# Player
# Adairialis76               2.28               1          2.280000
# Adastirin33                4.48               1          4.480000
# Aeda94                     4.91               1          4.910000
# Aela59                     4.32               1          4.320000
# Aelaria33                  1.79               1          1.790000
# Aelastirin39               7.29               2          3.645000
# Aelidru27                  1.09               1          1.090000
# Aelin32                    8.98               3          2.993333
# Aelly27                    6.79               2          3.395000
# Aellynun67                 3.74               1          3.740000
# Aellyria80                 3.08               1          3.080000
# Aelollo59                  5.63               2          2.815000
# Aenarap34                  2.96               1          2.960000
# ...

# %%
def f4(x):
    d = {}
    d['Purchase Average'] = (x['Price'].sum() / x['Purchase ID'].count())
    return pd.Series(d)

grouped_df = purchase_df.groupby('Player').apply(f4)
grouped_df.head()
# Out:
#               Purchase Average
# Player
# Adairialis76              2.28
# Adastirin33               4.48
# Aeda94                    4.91
# Aela59                    4.32
# Aelaria33                 1.79

# %%
gender_unique_df.head()

# %%
# # NOTE: INSERT NEW CALCULATED VALUES (each stored in a new variable like ) INTO PLACEHOLDERS: (...)

# # Create and display a summary data frame using above values
# gender_purchase_summary = pd.DataFrame({'Purchase Count': [...],
#                            'Average Purchase Price': '${:,.2f}'.format(...),
#                            'Total Purchase Value': [...],
#                            'Average Total Purchase per Person': '${:,.2f}'.format(...)})

# totals_summary_df
# # gender_purchase_summary.dtypes

# %%
# grouped_gender_df = grouped_gender.to_frame()

# # Rename 'Purchase ID' column to 'Purchase Count'
# grouped_gender.rename(columns = {'Purchase ID':'Purchase Count'}, inplace = True)

# # Purchase Count = 

# # Average Purchase Price

# # Total Purchase Value

# # Average Total Purchase per Person

# %%
# Create and display a summary data frame using above values

# %%
# Display summary

# %% [markdown]
# _____
#
# ### Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# SEE: http://localhost:8890/notebooks/UTAUS201810DATA2-copy/04_Pandas/3/Activities/03-Ins_Binning/Solved/Binning.ipynb

# %% [markdown]
# _____
#
# ### Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %% [markdown]
# _____
#
# ### Top Spenders
#
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ______
#
# ### Most Popular Items
#
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# _____
#
# ### Most Profitable Items
#
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
